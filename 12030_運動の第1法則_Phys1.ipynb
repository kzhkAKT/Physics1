# %% [markdown]
# # 力と運動の法則

# %% [markdown]
# ## 運動の第一法則(慣性の法則)

# %%
#@title 慣性の法則: だるま落とし
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/rJ_GzXH1JVA?si=tDTBJcrYRvRnN13K" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/rJ_GzXH1JVA?si=tDTBJcrYRvRnN13K" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
#@title 等速直線運度をする物体から投げ出された球の行方
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/MjAJU3eeXzQ?si=oSnnUd52jD3kHyHj" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/MjAJU3eeXzQ?si=oSnnUd52jD3kHyHj" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
#@title ISS での運動の第一法則の実験
# %%html
<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/Q0Wz5P0JdeU?si=Rv1mHdO7KOSWY09u" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/Q0Wz5P0JdeU?si=Rv1mHdO7KOSWY09u" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# > 物体に力がはたらかなければ,
# 静止している物体はいつまでも静止し続け,
# 運動している物体はいつまでも等速直線運動をつづける.
#
# 「物体に力がはたらかなければ」は **合力がゼロならば** ととらえてください.

# %%
#@title 合力における慣性の法則
# %%html
<iframe src="https://phet.colorado.edu/sims/html/forces-and-motion-basics/latest/forces-and-motion-basics_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/forces-and-motion-basics/latest/forces-and-motion-basics_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>
