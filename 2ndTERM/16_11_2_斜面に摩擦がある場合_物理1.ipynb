# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/Physics1/blob/draft/2ndTERM/16_11_2_%E6%96%9C%E9%9D%A2%E3%81%AB%E6%91%A9%E6%93%A6%E3%81%8C%E3%81%82%E3%82%8B%E5%A0%B4%E5%90%88_%E7%89%A9%E7%90%861.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 平面空間での運動

# %% [markdown]
# ## 斜面上にある物体の運動

# %% [markdown]
# ### 斜面に摩擦がある場合

# %%
#@title 摩擦のある斜面を滑る物体に働く力
#https://en.wikipedia.org/wiki/Frictionless_plane
# %%svg
<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" width="395px" viewBox="-0.5 -0.5 395 243" content="&lt;mxfile host=&quot;app.diagrams.net&quot; modified=&quot;2020-12-10T23:22:19.971Z&quot; agent=&quot;5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.67 Safari/537.36&quot; etag=&quot;khuwGXZSQbph_-Yjb-uY&quot; version=&quot;14.0.0&quot; type=&quot;google&quot;&gt;&lt;diagram id=&quot;p3RcUX4ShacrB7ML22gl&quot; name=&quot;Page-1&quot;&gt;...&lt;/diagram&gt;&lt;/mxfile&gt;" onclick="(function(svg){var src=window.event.target||window.event.srcElement;while (src!=null&amp;&amp;src.nodeName.toLowerCase()!='a'){src=src.parentNode;}if(src==null){if(svg.wnd!=null&amp;&amp;!svg.wnd.closed){svg.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&amp;&amp;evt.source==svg.wnd){svg.wnd.postMessage(decodeURIComponent(svg.getAttribute('content')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);svg.wnd=window.open('https://viewer.diagrams.net/?client=1&amp;page=0&amp;edit=_blank');}}})(this);" style="cursor:pointer;max-width:100%;max-height:243px;"><defs/><g><image x="54.5" y="-0.5" width="338.61" height="230" xlink:href="data:image/svg+xml;base64,..." preserveAspectRatio="none"/><path d="M 265 80 L 298.17 57.61" fill="none" stroke="#ff3333" stroke-width="2" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 303.15 54.25 L 298.75 62.04 L 298.17 57.61 L 294.28 55.41 Z" fill="#ff3333" stroke="#ff3333" stroke-width="2" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 41px; margin-left: 296px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 18px" face="Georgia" color="#ff3333"><i>f </i>'</font></div></div></div></foreignObject><text x="296" y="44" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">f '</text></switch></g><path d="M 85 180 L 21.7 225.21" fill="none" stroke="#000000" stroke-width="2" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 16.82 228.7 L 21 220.8 L 21.7 225.21 L 25.65 227.31 Z" fill="#000000" stroke="#000000" stroke-width="2" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 230px; margin-left: 5px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 20px" face="Georgia"><i>x</i></font></div></div></div></foreignObject><text x="5" y="234" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">x</text></switch></g><path d="M 82 190 L 36.79 126.7" fill="none" stroke="#000000" stroke-width="2" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 33.3 121.82 L 41.2 126 L 36.79 126.7 L 34.69 130.65 Z" fill="#000000" stroke="#000000" stroke-width="2" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 107px; margin-left: 23px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 20px" face="Georgia"><i>y</i></font></div></div></div></foreignObject><text x="23" y="111" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">y</text></switch></g></g><switch><g requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"/><a transform="translate(0,-5)" xlink:href="https://desk.draw.io/support/solutions/articles/16000042487" target="_blank"><text text-anchor="middle" font-size="10px" x="50%" y="100%">Viewer does not support full SVG 1.1</text></a></switch></svg>

# %% [markdown]
# 水平方向に対して, 傾角(けいかく) $\theta$ の **摩擦がある** 斜面を滑る
# 物体の運動方程式を考えます.

# %% [markdown]
# 出発点は, 瞬間を捉えることができる, 運動方程式
# \begin{align}
# m \vec{a} = \vec{F}
# \end{align}

# %% [markdown]
# $\require{color}$
# 物体の運動に合わせて
# - 斜面下向きを $x$軸の _正_
# - 斜面に対して垂直な方向を $y$軸の _正_
#
# >> 座標の取り方が、これまでと違っていることに注意してください.
#
# また,
# - 物体が動摩擦力 $f'$  を受けながら滑る
#   - 動摩擦力の大きさは $f'=\mu' N$
#
# として, 成分表示をすると

# %% [markdown]
# 重力ベクトル $\vec{W}$, 垂直抗力ベクトル $\vec{N}$, 動摩擦力 $\vec{f}$ は
#
# \begin{align}
# \vec{W}
#   =
#    \left(\begin{array}{c}
#     W_x \\
#     W_y
#   \end{array}
#   \right)
#   =
#    \left(\begin{array}{c}
#     {+mg \sin\theta} \\
#     {-mg \cos \theta}
#   \end{array}
#   \right),
# \qquad
# \vec{N} =   \left(\begin{array}{c}
#     0 \\
#     + N
#   \end{array}
# \right),
# \qquad
# \vec{f'} =   \left(\begin{array}{c}
#     \textcolor{red}{-f'} \\
#     0
#   \end{array}
# \right),
# \end{align}

# %% [markdown]
# 加速度ベクトル $\vec{a}$ もこの座標系を用いて
# \begin{align}
# \vec{a} =   \left(\begin{array}{c}
#     a_x \\
#     a_y
#   \end{array}
# \right),
# \end{align}
# とし,

# %% [markdown]
#  運動方程式のそれぞれの成分を表現すると
# \begin{align}
# m \vec{a} = \vec{F} = \vec{N} + \vec{W} + \textcolor{red}{\vec{f'}}:
# \quad
# \begin{cases}
# m a_x &= 0 + mg {\sin\theta} + \left(\textcolor{red}{-f'} \right)\\
# m a_y &= N + \left( - mg\cos\theta \right)
# \end{cases}
# \quad
# \to
# \quad
# \begin{cases}
# m a_x &= {mg \sin\theta} + \left(\textcolor{red}{-f'} \right)\\
# m a_y &= N {- mg\cos\theta}
# \end{cases}
# \end{align}

# %% [markdown]
# - 斜面を滑り落ちるときは, 物体は斜面に垂直な方向($y$軸)には
#   変位を生じない[飛んだり、跳ねたりしない]ので, $a_y = 0$

# %% [markdown]
# $\require{cancel}$
# \begin{align}
# \begin{cases}
# {m} a_x &= {{m}g \sin\theta} + \left(\textcolor{red}{-f'} \right)\\
# m \cancelto{0}{a_y}
#  &= N {- mg\cos\theta}
# \end{cases}
# \quad
# \to
# \quad
# \begin{cases}
# {m} a_x &= {{m}g \sin\theta} + \left(\textcolor{red}{-f'} \right)\\
#  N &= { mg\cos\theta}
# \end{cases}
# \end{align}

# %% [markdown]
# ここで動摩擦力の大きさ $\textcolor{red}{f'}$ へ, 垂直抗力 $N$ を代入し, 整理すると
# \begin{align*}
# m a_x &= m g \sin \theta - \mu' N \\[1mm]
# &= m g \sin \theta - \mu' m g \cos \theta \\[2mm]
# \bcancel{m} a_x &= \bcancel{m} g \left( \sin \theta - \mu' \cos \theta \right)\\[3mm]
# a_x &= g \left( \sin \theta - \mu' \cos \theta \right)
# \end{align*}

# %% [markdown]
# - 斜面方向 $x$ の加速度は, 斜面の角度によって決まり, 質量 $m$ によらない
#   - 動摩擦力の影響を受け, この加速度の大きさは, 摩擦のないときより _小さくなる_
# - 垂直抗力は, 力のつり合いから, $mg\cos\theta$
